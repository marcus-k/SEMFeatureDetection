# %% [markdown]
# # Test removing banners
#
# Testing removing banners from images. Inverting is needed for black banner instead of white ones.
# Sometimes the scale ticks are an issue. Weighing the vertical opened image more than the horizontal
# seems to fix this.

# %%
import sys
sys.path.insert(0, "../ellipsefinder/")

from preprocess.rmbanner import *
import cv2
import matplotlib.pyplot as plt

img = cv2.imread("../images/device1/device_1_q010.jpg")

out, banner, (imgv, imgh, imgf, bin2) = remove_banner(img, alpha=0.6, invert=True, _debug=True)

fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(img, cmap="gray")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(imgv, cmap="gray")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(imgh, cmap="gray")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(imgf, cmap="gray")

# %%
fig, ax = plt.subplots(figsize=(12, 12))
ax.imshow(out, cmap="gray")
